# %%
from nndet.io.load import load_pickle, save_pickle
from pathlib import Path

training_dir = Path("/opt/models/Task023_LUNA25/RetinaUNetV001_D3V001_3d/fold0")
plan = load_pickle(training_dir / "plan.pkl")
plan["inference_plan"] = {"iou_thresh": 0.5, "score_thresh": 0.0, "no_overlap": False}
save_pickle(plan, training_dir / "plan_inference.pkl")

# %%
from nndet.io.load import load_pickle, save_pickle
from pathlib import Path

plan = load_pickle("properties/D3V001_3d.pkl")

# %%
plan.keys()
# Out:
# dict_keys(['mode', 'target_spacing', 'normalization_schemes', 'use_mask_for_norm', 'anisotropy_threshold', 'resample_anisotropy_threshold', 'target_spacing_percentile', 'dim', 'num_modalities', 'all_classes', 'num_classes', 'transpose_forward', 'transpose_backward', 'dataset_properties', 'planner_id', 'network_dim', 'dataloader_kwargs', 'data_identifier', 'postprocessing', 'patch_size', 'batch_size', 'architecture', 'anchors', 'target_spacing_transposed', 'median_shape_transposed', 'do_dummy_2D_data_aug', 'trigger_lr1'])

# %%
from nndet.io.load import load_pickle, save_pickle
from pathlib import Path

training_dir = Path("/opt/data/beegfs/Task016_LUNA/preprocessed")
plan = load_pickle(training_dir / "D3V001_3d.pkl")

# %%
p = plan
print(p['patch_size'], p['batch_size'])
# Out:
# [ 80 192 192] 4
